# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plt.plot([x], y, [format])
plt.plot([0,1,2,3], [2,4,6,8])

# %%
# x is optional
plt.plot([2,4,6,8])

# %%
# plotting with markers instead of a line
plt.plot([0,1,2,3], [2,4,6,8], 'o')

# %%
# plotting multiple data points
plt.plot([2,4,6,8],'o',[1,5,9,13],'s')

# %%
# showing other properties
plt.plot([2,4,6,8], color='blue', marker='s', linestyle='dashed', linewidth=2, markersize=12)

# %%
# plotting from a dataframe
#plt.plot('x_key','y_key',data=df)

# %%
# manually setting xticks
plt.figure(figsize=(6,4))
plt.plot([2,4,6,8],'o',[1,5,9,13],'s')
plt.xticks(np.arange(4))
# Out:
# ([<matplotlib.axis.XTick at 0x7f8c87f55d50>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
# manually setting xticks another way
plt.figure(figsize=(6,4))
plt.plot([2,4,6,8],'o',[1,5,9,13],'s')
plt.xticks(np.arange(4), labels=['January','February','March','April'], rotation=20)
# Out:
# ([<matplotlib.axis.XTick at 0x7f8c87f33590>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
# saving plots
plt.figure()
plt.plot([1, 2, 4, 5], [1, 3, 4, 3],'-o')
plt.savefig('lineplot.png',dpi=300, bbox_inches='tight')
#bbox_inches='tight' removes the outer white margins

# %% [markdown]
# ### Plotting Stock prices of the Big-5

# %%
# google data
google_df = pd.read_csv('./datasets/stocks_data/GOOGL_data.csv')
google_df.head()
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL
# 1  2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL
# 2  2013-02-12  391.2659  394.3440  390.0747  390.7403  3714176  GOOGL
# 3  2013-02-13  390.4551  393.0677  390.3750  391.8214  2393946  GOOGL
# 4  2013-02-14  390.2549  394.7644  389.2739  394.3039  3466971  GOOGL

# %%
# microsft data
ms_df = pd.read_csv('./datasets/stocks_data/MSFT_data.csv')
ms_df.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
# facebook data
fb_df = pd.read_csv('./datasets/stocks_data/FB_data.csv')
fb_df.head()
# Out:
#          date   open   high    low    close    volume Name
# 0  2013-02-08  28.89  29.17  28.51  28.5450  37662614   FB
# 1  2013-02-11  28.61  28.68  28.04  28.2600  36979533   FB
# 2  2013-02-12  27.67  28.16  27.10  27.3700  93417215   FB
# 3  2013-02-13  27.36  28.32  27.31  27.9075  50100805   FB
# 4  2013-02-14  28.02  28.63  28.01  28.5000  35581045   FB

# %%
# amazon data
amazone_df = pd.read_csv('./datasets/stocks_data/AMZN_data.csv')
amazone_df.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
# apple
apple_df = pd.read_csv('./datasets/stocks_data/AAPL_data.csv')
apple_df.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
# create figure
plt.figure(figsize=(15,7), dpi=300)

# making plots
plt.plot('date','close', data=google_df, label='Google')
plt.plot('date','close', data=ms_df, label='Microsoft')
plt.plot('date','close', data=fb_df, label='Facebook')
plt.plot('date','close', data=amazone_df, label='Amazon')
plt.plot('date','close', data=apple_df, label='Apple')

# Specify ticks for x and y axis
plt.xticks(np.arange(0,1260,40), rotation=70)
plt.yticks(np.arange(0,1450,100))

#setting title
plt.title('Stock Trend for the BIG 5', fontsize=16)

# setting ylabel
plt.ylabel('Closing price in $', fontsize=14)

# adding grid
plt.grid()

# adding legend
plt.legend()

# %% [markdown]
# ### Barcharts

# %%
# format
# plt.bar(x, height, [width]) - default width is 0.8
# plt.barh(x, height, [width]) - horizontal barchart

# %%
plt.bar(['A','B','C','D'],[20,25,40,10])
# Out:
# <BarContainer object of 4 artists>

# %%
# creating sub-categories
labels = ['A','B','C','D']
x = np.arange(len(labels))
width = 0.4
plt.bar(x-width/2, [20,25,40,10], width=width)
# shifting the second bar by an offset equal to the width of the first bar creates sub-categories
plt.bar(x-width/2 +0.4, [30,15,30,20], width=width)

# Ticks
plt.xticks(x)

ax=plt.gca()
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'A'), Text(0, 0, 'B'), Text(0, 0, 'C'), Text(0, 0, 'D')]

# %% [markdown]
# ### Movie rating activity

# %%
movie_df = pd.read_csv('./datasets/movie_scores.csv')
movie_df.head()
# Out:
#    Unnamed: 0                         MovieTitle  Tomatometer  AudienceScore
# 0           0                 The Shape of Water           91             73
# 1           1                      Black Panther           97             79
# 2           2                            Dunkirk           92             81
# 3           3                        The Martian           91             91
# 4           4  The Hobbit: An Unexpected Journey           64             83

# %%
labels = movie_df['MovieTitle'].to_list()
labels
# Out:
# ['The Shape of Water',
#  'Black Panther',
#  'Dunkirk',
#  'The Martian',
#  'The Hobbit: An Unexpected Journey']

# %%
# create figure
plt.figure(figsize=(10,5), dpi=300)

# create barplot
pos = np.arange(len(movie_df['MovieTitle']))
width = 0.3

plt.bar(x-width/2, movie_df['Tomatometer'] ,width=width, label='Tomatometer')
plt.bar(x+width/2, movie_df['AudienceScore'], width=width, label='AudienceScore')

# specify ticks
plt.xticks(pos, rotation=10)
plt.yticks(np.arange(0,101,20))

# Get current Axes for setting tick labels and horizontal grid
ax = plt.gca()

# Set tick labels
ax.set_xticklabels(movie_df['MovieTitle'])
ax.set_yticklabels(['0%','20%','40%','60%','80%','100%'])

# Add minor ticks for y-axis in the interval of 5
ax.set_yticks(np.arange(0,100,5), minor=True)

# Add major horizontal grid with solid lines
ax.yaxis.grid(which='major')

# Add minor horizontal grid with dashed lines
ax.yaxis.grid(which='minor', linestyle='--')

# Add title
plt.title('Movie Comparison')

# Add legend
plt.legend()

# %% [markdown]
# ### Stacked bar plot

# %%
import seaborn as sns

# %%
# load dataset
bills = sns.load_dataset('tips')

# %%
bills.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
days = ['Thur','Fri','Sat','Sun']
days_range = np.arange(len(days))
smoker = ['Yes','No']

# %%
bills_by_days = [bills[bills['day'] == day] for day in days]

# %%
bills_by_days

# %%
bills_by_day_smoker =

# %%
# create figure
plt.figure(figsize=(10,5), dpi=300)

# Create stacked bar plot
plt.bar()

# %% [markdown]
# ### Plotting images

# %%
import matplotlib.image as mpimg
import os

# %%
# Load images
img_filenames = sorted(os.listdir('./datasets/imgs/'))
imgs = [mpimg.imread(os.path.join('./datasets/imgs/', img_filename)) for img_filename in img_filenames]

# %%
img_filenames
# Out:
# ['photo-1.jpg', 'photo-2.jpg', 'photo-3.jpg', 'photo-4.jpg']

# %%
imgs
# Out:
# [array([[[217, 217, 229],
#          [218, 218, 230],
#          [218, 218, 230],
#          ...,
#          [237, 225, 225],
#          [236, 224, 224],
#          [236, 224, 224]],
#
#         [[218, 218, 230],
#          [218, 218, 230],
#          [218, 218, 230],
#          ...,
#          [237, 225, 225],
#          [236, 224, 224],
#          [236, 224, 224]],
#
#         [[219, 219, 229],
#          [219, 219, 229],
#          [219, 219, 229],
#          ...,
#          [236, 224, 224],
#          [236, 224, 224],
#          [235, 223, 223]],
#
#         ...,
#
#         [[ 38,  37,  53],
#          [ 38,  37,  53],
#          [ 38,  37,  53],
#          ...,
#          [ 37,  39,  54],
#          [ 37,  39,  52],
#          [ 37,  39,  52]],
#
#         [[ 38,  37,  53],
#          [ 38,  37,  53],
#          [ 38,  37,  53],
#          ...,
#          [ 37,  39,  54],
#          [ 37,  39,  54],
#          [ 37,  39,  54]],
#
#         [[ 38,  37,  53],
# ...

# %%
# visualizing images in 2X2 image grid
fig, axes = plt.subplots(2,2)
fig.figsize= (6,6)
fig.dpi = 150
axes = axes.ravel()

# specify labels
labels = ['coast','beach','building','city at night']

# plot images
for i in range(len(imgs)):
    axes[i].imshow(imgs[i])
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    axes[i].set_xlabel(labels[i])

# %% [markdown]
# ### Creating a Scatter Plot with Marginal Histograms

# %%
data = pd.read_csv('./datasets/anage_data.csv')
data.head()
# Out:
#    Unnamed: 0  HAGRID   Kingdom      Phylum         Class        Order  \
# 0           0       3  Animalia  Arthropoda  Branchiopoda  Diplostraca
# 1           1       5  Animalia  Arthropoda       Insecta      Diptera
# 2           2       6  Animalia  Arthropoda       Insecta  Hymenoptera
# 3           3       8  Animalia  Arthropoda       Insecta  Hymenoptera
# 4           4       9  Animalia  Arthropoda       Insecta  Hymenoptera
#
#           Family          Genus       Species              Common name  ...  \
# 0     Daphniidae        Daphnia     pulicaria                  Daphnia  ...
# 1  Drosophilidae     Drosophila  melanogaster                Fruit fly  ...
# 2         Apidae           Apis     mellifera                Honey bee  ...
# 3     Formicidae  Cardiocondyla     obscurior  Cardiocondyla obscurior  ...
# 4     Formicidae         Lasius         niger         Black garden ant  ...
#
#    Growth rate (1/days)  Maximum longevity (yrs)  Specimen origin  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'HAGRID', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family',
#        'Genus', 'Species', 'Common name', 'Female maturity (days)',
#        'Male maturity (days)', 'Gestation/Incubation (days)', 'Weaning (days)',
#        'Litter/Clutch size', 'Litters/Clutches per year',
#        'Inter-litter/Interbirth interval', 'Birth weight (g)',
#        'Weaning weight (g)', 'Adult weight (g)', 'Growth rate (1/days)',
#        'Maximum longevity (yrs)', 'Specimen origin', 'Sample size',
#        'Data quality', 'IMR (per yr)', 'MRDT (yrs)', 'Metabolic rate (W)',
#        'Body mass (g)', 'Temperature (K)'],
#       dtype='object')

# %% [markdown]
# Filter the data so that you end up with samples containing a body mass and a maximum longevity as the given dataset is not complete. Select all the samples of the aves class and with a body mass smaller than 20,000.

# %%
# Preprocessing

longevity = 'Maximum longevity (yrs)'
mass = 'Body mass (g)'

# %%
data = data[np.isfinite(data[longevity]) & np.isfinite(data[mass])] 

# Sort according to class
aves = data[(data['Class'] == 'Aves') & (data[mass]<20000)]
aves.head()
# Out:
#      Unnamed: 0  HAGRID   Kingdom    Phylum Class            Order  \
# 184         184     192  Animalia  Chordata  Aves  Accipitriformes
# 189         189     197  Animalia  Chordata  Aves  Accipitriformes
# 199         199     207  Animalia  Chordata  Aves  Accipitriformes
# 214         214     222  Animalia  Chordata  Aves  Accipitriformes
# 232         232     240  Animalia  Chordata  Aves  Accipitriformes
#
#            Family        Genus       Species                  Common name  \
# 184  Accipitridae    Accipiter         nisus         Eurasian sparrowhawk
# 189  Accipitridae       Aquila    chrysaetos                 Golden eagle
# 199  Accipitridae        Buteo      lineatus          Red-shouldered hawk
# 214  Accipitridae  Geranoaetus  melanoleucus  Black-chested buzzard-eagle
# 232  Accipitridae       Pernis      apivorus        Western honey-buzzard
#
#      ...  Growth rate (1/days)  Maximum longevity (yrs)  Specimen origin  \
# ...

# %%
# Create figure
fig = plt.figure(figsize=(6,6), dpi=100, constrained_layout=True)
# Create gridspec
gs = fig.add_gridspec(3,3)
# Specify subplots
histx_ax = fig.add_subplot(gs[0,:-1])
histy_ax = fig.add_subplot(gs[1:,-1])
scatter_ax = fig.add_subplot(gs[1:,:-1])
# Create plots
scatter_ax.scatter(aves[mass],aves[longevity])
histx_ax.hist(aves[mass],bins=20, density=True)
histx_ax.set_xticks([])
histy_ax.hist(aves[longevity],bins=20, density=True, orientation='horizontal')
histy_ax.set_xticks([])
# Add labels and title
plt.xlabel('Body mass in grams')
plt.ylabel('Maximum longevity in years')
plt.suptitle('Scatter plot with marginal histogram')
# Out:
# Text(0.5, 0.98, 'Scatter plot with marginal histogram')

# %% [markdown]
# ### Using a Histogram and a Box Plot to Visualize Intelligence Quotient

# %%
# IQ samples
iq_scores = [126,  89,  90, 101, 102,  74,  93, 101,  66, 120, 108,  97,  98, 105, 119,  92, 113,  81, 104, 108,  83, 102, 105, 111, 102, 107, 103,  89,  89, 110,  71, 110, 120,  85, 111,  83, 122, 120, 102, 84, 118, 100, 100, 114,  81, 109,  69,  97,  95, 106, 116, 109, 114,  98,  90,  92,  98,  91,  81,  85,  86, 102,  93, 112,  76, 89, 110,  75, 100,  90,  96,  94, 107, 108,  95,  96,  96, 114, 93,  95, 117, 141, 115,  95,  86, 100, 121, 103,  66,  99,  96, 111, 110, 105, 110, 91, 112, 102, 112,  75]

# %% [markdown]
# __IQ scores are normally distributed with a mean of 100 and a standard deviation of 15.__

# %%
# create figure
plt.figure(figsize=(6,4), dpi=100)

# Create histogram
plt.hist(iq_scores, bins=10)
plt.axvline(x=100, color='r')
plt.axvline(x=115, color='r',linestyle='--')
plt.axvline(x=85, color='r', linestyle='--')

# Add labels and title
plt.xlabel('IQ Score')
plt.ylabel('Frequency')
plt.title('IQ scores for a test group of a hundred adults')
# Out:
# Text(0.5, 1.0, 'IQ scores for a test group of a hundred adults')

# %%
# create figure
plt.figure(figsize=(6,4), dpi=100)

# create boxplot
plt.boxplot(iq_scores)

# Add labels and title
ax = plt.gca()
ax.set_xticklabels(['Test Group'])
plt.ylabel('IQ Score')
plt.title('IQ scores for a test group of a hundred adults')
# Out:
# Text(0.5, 1.0, 'IQ scores for a test group of a hundred adults')
